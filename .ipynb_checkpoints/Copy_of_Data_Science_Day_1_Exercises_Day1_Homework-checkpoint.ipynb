# %% [markdown]
# # Exercises

# %% [markdown]
# ### #1 - Calculate the BMI (body mass index) on the two lists below using NDArrays...

# %%
import numpy as np
# formula = weight / (height**2) * 730
height = [69, 70, 71, 72, 73, 74, 75]
weight = [110, 120, 130, 140, 150, 160, 170]

bmi = 750 * np.array(weight) / (np.array(height) ** 2)
bmi = bmi.astype(np.int64)
print(bmi)
# Out:
# [17 18 19 20 21 21 22]

# %% [markdown]
# ### #2 - Create a function that will take in two parameters and will create a random matrix based off of those parameters. Extra: Have additional parameters taken in that allow the user to choose the shape and data type of the matrix.

# %%
import numpy as np
from numpy import random

def rand_matrix(minNum, maxNum, in_shape = 'random', data_type = 'i'):
    '''
    All matrices created as integers except float type, then changed to given data type.
    inputs: minimum number: Required. Must be integer.
            maximum number: Required. Must be integer.
            shape: Optional. Defaults to random.  Must be integer or tuple.
            data type: Optional. Defaults to integer. If shape not specified, must specify as 'data_type ='
    '''
    from numpy import random
    
    if in_shape == 'random':
        x_size = np.random.randint(0,50)
        y_size = np.random.randint(0,50)
        z_size = np.random.randint(0,50)
        in_shape = (x_size, y_size, z_size)
        print(in_shape)
    elif isinstance(in_shape,tuple):
        print(f'shaped passed is a tuple: {in_shape}')
    else:
        try:
            in_shape = int(in_shape)
        except:
            print(f'shape was passed as {in_shape} with type {type(in_shape)}')
            return "Invalid entry for shape.  Must be integer or tuple of integers. Error_1"
        

    if data_type == 'i' or data_type == 'int64':
        M = random.randint(maxNum, size = in_shape)
    elif data_type == 'f':
        if isinstance(in_shape, tuple):
            if len(in_shape) == 2:
                M = random.rand(in_shape[0], in_shape[1])
            elif len(in_shape) == 3:
                M = random.rand(in_shape[0], in_shape[1], in_shape[2])
            elif len(in_shape) == 4:
                M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3])
            elif len(in_shape) == 5:
                M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3], in_shape[4])
            elif len(in_shape) == 6:
                M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3], in_shape[4], in_shape[5])
            else:
                print(f"input shape {in_shape} too long for support of this function.")
                return "Limit to 6 elements"
            
            # print(f'M = \n{M}')  ### For Debugging
            M2 = random.randint(minNum, maxNum, size = in_shape)
            # print(f'M2 = \n{M2}')  ### For Debugging
            M = M + M2
            # print(f'M = \n{M}')  ### For Debugging

        else:
            M = random.rand(in_shape)
            M2 = random.randint(minNum, maxNum, in_shape)
            M = M + M2
            # print(f'M = \n{M}')  ### For Debugging
    elif data_type == 'b':
        M = random.randint(0, 2, size = in_shape)
        M = M.astype('b')
    elif data_type == 'u':        ############ 'u' not recognized as valid data type
        print("Unicode not supported at this time.")
        # M = random.randint(minNum, maxNum, in_shape)
        # M = M.astype('u')
    elif data_type == 'c':
        return "Debugging taking too more time than it's worth."
        # if isinstance(in_shape, tuple):
        #     if len(in_shape) == 2:
        #         M1 = random.rand(in_shape[0], in_shape[1])
        #     elif len(in_shape) == 3:
        #         M1 = random.rand(in_shape[0], in_shape[1], in_shape[2])
        #     elif len(in_shape) == 4:
        #         M1 = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3])
        #     elif len(in_shape) == 5:
        #         M1 = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3], in_shape[4])
        #     elif len(in_shape) == 6:
        #         M1 = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3], in_shape[4], in_shape[5])
        #     else:
        #         print(f"input shape {in_shape} too long for support of this function.")
        #         return "Limit to 6 elements"
        # else:
        #     M1 = random.rand(in_shape)
        # M1 = M1.astype('c')
        # M2 = random.randint(minNum, maxNum, in_shape)
        # M2 = M2.astype('c')
        # M = np.concatenate(M2,M1)
    elif data_type == 'm':  ## Time Delta
        if isinstance(in_shape, tuple):
            if len(in_shape) == 2:
                M = random.rand(in_shape[0], in_shape[1])
            elif len(in_shape) == 3:
                M = random.rand(in_shape[0], in_shape[1], in_shape[2])
            elif len(in_shape) == 4:
                M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3])
            elif len(in_shape) == 5:
                M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3], in_shape[4])
            elif len(in_shape) == 6:
                M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3], in_shape[4], in_shape[5])
            else:
                print(f"input shape {in_shape} too long for support of this function.")
                return "Limit to 6 elements"
            
            # print(f'M = \n{M}')  ### For Debugging
            M2 = random.randint(minNum, maxNum, size = in_shape)
            # print(f'M2 = \n{M2}')  ### For Debugging
            M = M + M2
            # print(f'M = \n{M}')  ### For Debugging
        else:
            M = random.rand(in_shape)
            M2 = random.randint(minNum, maxNum, in_shape)
            M = M + M2
            # print(f'M = \n{M}')  ### For Debugging
        M = M.astype('m')
    elif data_type == 'M':
          return "Debugging taking too more time than it's worth."
      
        # if isinstance(in_shape, tuple):
        #     if len(in_shape) == 2:
        #         M = random.rand(in_shape[0], in_shape[1])
        #     elif len(in_shape) == 3:
        #         M = random.rand(in_shape[0], in_shape[1], in_shape[2])
        #     elif len(in_shape) == 4:
        #         M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3])
        #     elif len(in_shape) == 5:
        #         M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3], in_shape[4])
        #     elif len(in_shape) == 6:
        #         M = random.rand(in_shape[0], in_shape[1], in_shape[2], in_shape[3], in_shape[4], in_shape[5])
        #     else:
        #         print(f"input shape {in_shape} too long for support of this function.")
        #         return "Limit to 6 elements"
            
        #     # print(f'M = \n{M}')  ### For Debugging
        #     M2 = random.randint(minNum, maxNum, size = in_shape)
        #     # print(f'M2 = \n{M2}')  ### For Debugging
        #     M = M + M2
        #     # print(f'M = \n{M}')  ### For Debugging
        # else:
        #     M = random.rand(in_shape)
        #     M2 = random.randint(minNum, maxNum, in_shape)
        #     M = M + M2
        #     # print(f'M = \n{M}')  ### For Debugging
        # M = M.astype('M')
    elif data_type == 'O':
        M = random.randint(minNum, maxNum, in_shape)
        M = M.astype('O')
    elif data_type == 'S':
        M = random.randint(minNum, maxNum, in_shape)
        M = M.astype('S')
    elif data_type == 'U':
        M = random.randint(minNum, maxNum, in_shape)
        M = M.astype('U')
    elif data_type == 'V':
        M = random.randint(minNum, maxNum, in_shape)
        M = M.astype('V')
    else:
        print('\nInvalid datatype. Must select from:')
        print('i - integer')
        print('b - boolean')
        print('u - unsigned integer')
        print('f - float')
        print('c - complex float')
        print('m - timedelta')
        print('M - datetime')
        print('O - object')
        print('S - string')
        # print('U - unicode string')
        print('V - fixed chunk of memory for other type ( void )')

    return M
            
print(rand_matrix(0, 100, data_type = 'f'))
# Out:
# (29, 38, 18)
# [[[95.60801644 67.04702755  8.51918701 ... 24.43594375 79.99821445
#    40.33950099]
#   [ 5.31399543  8.25510618 47.03825787 ...  0.9314715  25.0895421
#    44.49874801]
#   [ 6.14781163 27.94272149 41.90203457 ...  7.81429339 23.43005207
#    42.60361535]
#   ...
#   [31.33298025 83.04091133 51.48280471 ... 14.6763474  29.28979653
#    72.6365985 ]
#   [71.13468381 18.51739502 36.00463636 ... 64.82886189 92.53801805
#    47.33397451]
#   [29.27971521 71.93982789 15.9977399  ... 57.78650749 39.77715979
#    99.41507393]]
#
#  [[ 0.26958924 95.64726791  7.11742216 ... 36.13937503 29.0179724
#    44.58328957]
#   [16.70333464 94.11359546 11.76071313 ... 23.30410235 26.35531336
#     1.71171414]
#   [76.99784725 26.05230918 69.19938822 ... 69.9530808  79.52005156
#    46.42210817]
#   ...
#   [34.78747329 92.32355238 89.61191509 ... 11.58220949  2.38707169
#    96.22895072]
#   [75.36343993 50.29615672 33.55030131 ... 78.11137092 12.62567779
#    64.34546574]
#   [91.90191366 59.84234653 75.56933436 ... 80.22480186 60.13823861
#    29.92160663]]
#
#  [[30.59491051 99.29838712 31.68500477 ... 40.69700213 23.48492378
#    28.74288153]
#   [99.72861673  4.29446355 68.73888863 ... 22.30410416 82.03249544
#    94.25324683]
#   [76.25944037 98.41369882 95.68190063 ... 82.73933872 49.24608578
#    66.02624133]
#   ...
#   [77.56982196  7.34362062  0.24844588 ... 44.63622247 19.73890762
#    60.41178289]
#   [62.92549784 89.00401362 90.28748921 ... 17.3530288  68.36159155
#    49.26334148]
#   [55.51241653  9.76101603  2.59105429 ... 21.17778758 71.716782
#    97.27116952]]
#
#  ...
#
#  [[30.15316791 56.55116517 96.70707767 ... 12.47478531 11.15081153
#    80.61534491]
#   [32.71996052 99.09894598 39.00843629 ... 29.20418794 41.60407519
#    79.11299522]
#   [55.15968846 12.56570825 53.85046008 ... 78.13302643 15.67882775
#    55.65058707]
#   ...
#   [48.31180438 27.78448661 35.82834533 ... 36.25890478 97.18351838
#    91.24004713]
#   [17.06208312  3.82117594 78.3646516  ... 41.04866367 71.74169067
#    94.80208306]
#   [80.12353313 30.19089429 24.05560996 ... 80.307117   55.37829627
#    75.78408663]]
#
#  [[68.2007042  11.70241242  3.43643038 ... 84.64093899 61.30680809
#    16.36037045]
#   [74.05373077 38.23138783 77.20555416 ...  1.95137171 48.6439505
#    10.61523648]
#   [60.51866091 39.55142703 49.99564245 ... 85.75838378 67.82955613
#    63.29548005]
#   ...
#   [ 1.76193549 18.18588318 40.86188395 ... 64.41516935 51.11323171
#     4.0012604 ]
#   [11.05341712 30.93696216 48.55533757 ... 71.84539842  8.63145845
#    52.10970663]
#   [84.6996062  81.0865724  60.62455372 ... 93.81832192 68.86198093
#    14.63570221]]
#
#  [[49.14829563 70.81168778 38.49762799 ... 61.39941352 34.00689669
#    15.79823246]
#   [80.24973856 46.85644242 14.95906396 ... 51.49444983 41.42445976
#    98.08304175]
#   [64.62866031  9.71861245 52.38543962 ... 14.77678897 19.07874332
#    68.72160752]
#   ...
#   [49.32387052 88.36615252 59.41810524 ... 54.43096226 98.8564765
#    82.81264004]
#   [ 8.34532971 69.38007386 64.5284584  ... 40.07055488 62.15661744
#    73.48021987]
#   [97.11665286 73.09682288  7.46725649 ... 22.09804666 12.02245565
#    51.4294004 ]]]

# %% [markdown]
# ### #3 - Extra: Open and load the data in the two text files that have the Boston Red Sox hitting data for the past seasons. Compare the difference in the two years by putting the data into an NDArray and running a differencial operation on it. The column to look for will be SLG.
#
# Your output should display which year (either 2017 or 2018) was a better year based on SLG

# %%
import csv
import numpy as np

###  Copy & paste  ###

FIELDS = ['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 
          'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB']

DATATYPES = [('rk', 'i'), ('pos', '|S25'), ('name', '|S25'), ('age', 'i'), ('g', 'i'), ('pa', 'i'), ('ab', 'i'),
                ('r', 'i'), ('h', 'i'), ('2b', 'i'), ('3b', 'i'), ('hr', 'i'), ('rbi', 'i'), ('sb', 'i'), ('cs', 'i'),
                ('bb', 'i'), ('so', 'i'), ('ba', 'f'), ('obp', 'f'), ('slg', 'f'), ('ops', 'f'), ('opsp', 'i'),
                ('tb', 'i'), ('gdp', 'i'), ('hbp', 'i'), ('sh', 'i'), ('sf', 'i'), ('ibb', 'i')]




def load_data(filename, d = ', '): ###### Had to adjust files to have ', ' rather than just ','
    data = np.genfromtxt(filename,delimiter = d, skip_header = 1,
                        usecols = np.arange(0,24),invalid_raise=False,
                        names = FIELDS, dtype = DATATYPES)
    return data

############## My code #############

bs2017 = load_data('redsox_2017_hitting.txt')
bs2018 = load_data('redsox_2018_hitting.txt')

SLG_2017 = bs2017['SLG']
SLG_2018 = bs2018['SLG']

SLG_2017 = SLG_2017.tolist()
SLG_2018 = SLG_2018.tolist()

type(SLG_2017)

avg_SLG_2017 = sum(SLG_2017)/len(SLG_2017)
avg_SLG_2018 = sum(SLG_2018)/len(SLG_2018)
print(f'Average SLG: \n 2017: {avg_SLG_2017}\n 2018: {avg_SLG_2018}')
if avg_SLG_2017 > avg_SLG_2018:
    print(f'\n2017 was a better year, with {avg_SLG_2017} SLG.')
else:
    print(f'\n2018 was a better year, with {avg_SLG_2018} SLG.')
# Out:
# Average SLG:
#  2017: 0.39334782374941785
#  2018: 0.38750000335276125
#
# 2017 was a better year, with 0.39334782374941785 SLG.

# %%
FIELDS = ['Rk', 'Pos', 'Name', 'Age', 'G', 'PA', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'SB', 'CS', 
          'BB', 'SO', 'BA', 'OBP', 'SLG', 'OPS', 'OPS+', 'TB', 'GDP', 'HBP', 'SH', 'SF', 'IBB']

DATATYPES = [('rk', 'i'), ('pos', '|S25'), ('name', '|S25'), ('age', 'i'), ('g', 'i'), ('pa', 'i'), ('ab', 'i'),
                ('r', 'i'), ('h', 'i'), ('2b', 'i'), ('3b', 'i'), ('hr', 'i'), ('rbi', 'i'), ('sb', 'i'), ('cs', 'i'),
                ('bb', 'i'), ('so', 'i'), ('ba', 'f'), ('obp', 'f'), ('slg', 'f'), ('ops', 'f'), ('opsp', 'i'),
                ('tb', 'i'), ('gdp', 'i'), ('hbp', 'i'), ('sh', 'i'), ('sf', 'i'), ('ibb', 'i')]

#Use this function to actually open the data inside of a NDArray
